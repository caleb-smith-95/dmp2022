# %%
import pandas as pd
import plotly.express as px
import numpy as np
# %matplotlib inline
from itertools import repeat
from urllib.request import urlopen
import html5lib
import ssl
import time

# %%
off78 = pd.read_html("https://www.pro-football-reference.com/years/NFL/index.htm")
comb_off = off78[0]
comb_off.columns = comb_off.columns.droplevel()
comb_off
# Out:
#       Rk  Year Tms    PF    Yds   Ply  Y/P   TO   FL  1stD  ... 1stD  Pen  \
# 0      1  2021  32  23.0  343.6  63.3  5.4  1.3  0.5  20.3  ...  6.7  5.9
# 1      2  2020  32  24.8  359.0  64.3  5.6  1.3  0.5  21.7  ...  7.0  5.6
# 2      3  2019  32  22.8  347.9  63.5  5.5  1.4  0.6  20.3  ...  6.1  6.7
# 3      4  2018  32  23.3  352.2  62.9  5.6  1.4  0.5  20.4  ...  6.3  6.7
# 4      5  2017  32  21.7  334.1  63.4  5.3  1.4  0.5  19.3  ...  5.7  6.7
# ..   ...   ...  ..   ...    ...   ...  ...  ...  ...   ...  ...  ...  ...
# 98    96  1926  22   7.6    NaN   NaN  NaN  NaN  0.0   NaN  ...  NaN  0.0
# 99    97  1925  20   8.9    NaN   NaN  NaN  NaN  0.0   NaN  ...  NaN  0.0
# 100   98  1924  18  10.4    NaN   NaN  NaN  NaN  0.0   NaN  ...  NaN  0.0
# 101   99  1923  20   7.9    NaN   NaN  NaN  NaN  0.0   NaN  ...  NaN  0.0
# 102  100  1922  18   9.1    NaN   NaN  NaN  NaN  0.0   NaN  ...  NaN  0.0
#
#       Yds 1stPy   #Dr   Sc%   TO% Plays   Yds   Pts
# ...

# %%
comb_off.columns
# Out:
# Index(['Rk', 'Year', 'Tms', 'PF', 'Yds', 'Ply', 'Y/P', 'TO', 'FL', '1stD',
#        'Cmp', 'Att', 'Yds', 'TD', 'Int', 'NY/A', '1stD', 'Att', 'Yds', 'TD',
#        'Y/A', '1stD', 'Pen', 'Yds', '1stPy', '#Dr', 'Sc%', 'TO%', 'Plays',
#        'Yds', 'Pts'],
#       dtype='object')

# %%
comb_off2 = comb_off.drop(columns = ['Rk', 'Y/P', '1stD',
       'NY/A', '1stD',
       'Y/A', '1stD', '#Dr', 'Sc%', 'TO%', 'Plays',
       'Pts'])

# %%
comb_off2.tail(11)
# Out:
#      Year Tms    PF    Yds   Ply   TO   FL  Cmp   Att   Yds   TD  Int   Att  \
# 92   1932   8   8.2  165.1  44.6  1.0  0.0  3.9  10.9  55.2  0.4  1.0  33.7
# 93   1931  10   9.9    NaN   NaN  NaN  0.0  0.0   0.0   0.0  0.5  0.0   0.0
# 94   1930  11  10.6    NaN   NaN  NaN  0.0  0.0   0.0   0.0  0.5  0.0   0.0
# 95   1929  12   9.5    NaN   NaN  NaN  0.0  0.0   0.0   0.0  0.6  0.0   0.0
# 96   1928  10   9.5    NaN   NaN  NaN  0.0  0.0   0.0   0.0  0.6  0.0   0.0
# 97   1927  12   9.1    NaN   NaN  NaN  0.0  0.0   0.0   0.0  0.4  0.0   0.0
# 98   1926  22   7.6    NaN   NaN  NaN  0.0  0.0   0.0   0.0  0.3  0.0   0.0
# 99   1925  20   8.9    NaN   NaN  NaN  0.0  0.0   0.0   0.0  0.4  0.0   0.0
# 100  1924  18  10.4    NaN   NaN  NaN  0.0  0.0   0.0   0.0  0.4  0.0   0.0
# 101  1923  20   7.9    NaN   NaN  NaN  0.0  0.0   0.0   0.0  0.3  0.0   0.0
# 102  1922  18   9.1    NaN   NaN  NaN  0.0  0.0   0.0   0.0  0.2  0.0   0.0
#
#        Yds   TD  Pen  Yds 1stPy  Yds
# ...

# %%
comb_off2.columns
# Out:
# Index(['Year', 'Tms', 'PF', 'Yds', 'Ply', 'TO', 'FL', 'Cmp', 'Att', 'Yds',
#        'TD', 'Int', 'Att', 'Yds', 'TD', 'Pen', 'Yds', '1stPy', 'Yds'],
#       dtype='object')

# %%
comb_off3 = comb_off2.set_axis(['Year', 'Num_Teams', 'Points/G', 'Yds/G', 'Plays', 'TO', 'Fumbles', 'Cmp', 'Pass Att', 'Pass Yds',
       'Pass TD', 'Int', 'Rush Att', 'Rush Yds', 'Rush TD', 'Drop', 'Drop', 'Drop', 'Drop'], axis = 1)
comb_off3.drop(columns = ['Drop'], inplace = True)
comb_off3.tail(11)
# Out:
#      Year Num_Teams Points/G  Yds/G Plays   TO Fumbles  Cmp Pass Att Pass Yds  \
# 92   1932         8      8.2  165.1  44.6  1.0     0.0  3.9     10.9     55.2
# 93   1931        10      9.9    NaN   NaN  NaN     0.0  0.0      0.0      0.0
# 94   1930        11     10.6    NaN   NaN  NaN     0.0  0.0      0.0      0.0
# 95   1929        12      9.5    NaN   NaN  NaN     0.0  0.0      0.0      0.0
# 96   1928        10      9.5    NaN   NaN  NaN     0.0  0.0      0.0      0.0
# 97   1927        12      9.1    NaN   NaN  NaN     0.0  0.0      0.0      0.0
# 98   1926        22      7.6    NaN   NaN  NaN     0.0  0.0      0.0      0.0
# 99   1925        20      8.9    NaN   NaN  NaN     0.0  0.0      0.0      0.0
# 100  1924        18     10.4    NaN   NaN  NaN     0.0  0.0      0.0      0.0
# 101  1923        20      7.9    NaN   NaN  NaN     0.0  0.0      0.0      0.0
# 102  1922        18      9.1    NaN   NaN  NaN     0.0  0.0      0.0      0.0
#
# ...

# %%
comb_off4 = comb_off3.drop(range(93,103))
comb_off4
# Out:
#     Year Num_Teams Points/G  Yds/G Plays   TO Fumbles   Cmp Pass Att Pass Yds  \
# 0   2021        32     23.0  343.6  63.3  1.3     0.5  22.3     34.4    228.3
# 1   2020        32     24.8  359.0  64.3  1.3     0.5  23.0     35.2    240.2
# 2   2019        32     22.8  347.9  63.5  1.4     0.6  22.1     34.9    235.0
# 3   2018        32     23.3  352.2  62.9  1.4     0.5  22.4     34.5    237.8
# 4   2017        32     21.7  334.1  63.4  1.4     0.5  21.2     34.2    224.4
# ..   ...       ...      ...    ...   ...  ...     ...   ...      ...      ...
# 88  1935         9     10.9  196.2  54.2  2.2     0.0   5.2     15.4     79.7
# 89  1934        11     10.8  200.7  50.4  1.7     0.0   4.2     13.4     59.3
# 90  1933        10      9.7  198.9  50.4  2.2     0.0   5.1     14.3     77.9
# 91  Year       Tms       PF    Yds   Ply   TO      FL   Cmp      Att      Yds
# 92  1932         8      8.2  165.1  44.6  1.0     0.0   3.9     10.9     55.2
#
# ...

# %%
off_clean = comb_off4.Year != 'Year'
off_final = comb_off4[off_clean]
off_final.reset_index(inplace = True)
off_final.drop(columns = 'index', inplace = True)
off_final
# Out:
# C:\Users\caleb\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#     Year Num_Teams Points/G  Yds/G Plays   TO Fumbles   Cmp Pass Att Pass Yds  \
# 0   2021        32     23.0  343.6  63.3  1.3     0.5  22.3     34.4    228.3
# 1   2020        32     24.8  359.0  64.3  1.3     0.5  23.0     35.2    240.2
# 2   2019        32     22.8  347.9  63.5  1.4     0.6  22.1     34.9    235.0
# 3   2018        32     23.3  352.2  62.9  1.4     0.5  22.4     34.5    237.8
# 4   2017        32     21.7  334.1  63.4  1.4     0.5  21.2     34.2    224.4
# ..   ...       ...      ...    ...   ...  ...     ...   ...      ...      ...
# 85  1936         9     11.9  225.3  56.6  2.0     0.0   5.6     15.3     83.0
# ...

# %%
off_final.to_csv('C:/Users/caleb/OneDrive/Documents/Spring 2022 Classes/Directed Masters Project/Clean Data/Combined/Season Y per G.csv')
